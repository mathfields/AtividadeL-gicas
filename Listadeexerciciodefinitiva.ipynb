# %%
print ("Adição")

a = int (input("Digite um número;"))
b = int (input("Digite um número;"))
soma = int

soma = a + b

print ("O resultado da soma é:", soma)
# Out:
# Adição
# Digite um número;4
# Digite um número;5
# O resultado da soma é: 9

# %%
print ("Subtração")

a = float (input("Digite um número;"))
b = float (input("Digite um número;"))
sub = float

sub = a - b

print ("O resultado da subtração é:", sub)

# %%
print ("Multiplicação")

a = int (input("Digite um número;"))
b = int (input("Digite um número;"))
multi = int

multi = a * b

print ("O resultado da multiplicação é:", multi)

# %%
print ("Antecessor e sucessor")

a = int (input("Digite um número;"))
sucessor = int
antecessor = int

sucessor = a + 1
antecessor = a -1

print ("Seu sucessor é:", sucessor)
print ("Seu antecessor é:", antecessor)

# %%
print ("dobro e triplo")

a = int (input("Digite um número;"))
dobro = int
triplo = int

dobro = a * 2
triplo = a * 3


print ("O dobro do número digitado é", dobro)
print("e o triplo é:", triplo)

# %%
print ("Area do triangulo")

a = float (input("Digite o valor da base;"))
b = float (input("Digite o valor da altura;"))
area = float

area = (a*b)/2

print ("A area do triangulo é:", area)

# %%
print ("Perimetro do retangulo")
b = int (input("Digite o valor da base;"))
h = int (input("Digite o valor da altura;"))
p = float

p = 2 * (b+h)

print ("O perimetro do retangulo é:", p)

# %%
print ("Impar ou par")

numero = int(input("Digite um numero:"))

if numero %2 == 0:
  print ("Seu numero é par")

else:
  print("Seu numero é impar")

# %%
print ("Negativo ou positivo")

numero = int (input("Digite um numero"))

if numero > 0:
  print("Seu numero é positivo")

elif numero < 0:
    print("Seu numero é negativo")


else:
  print("Seu numero é 0")

# %%
print("Qual dos três é maior?")

a = float(input("Escreva um numero:"))
b = float(input("Escreva um numero:"))
c = float(input("Escreva um numero:"))
maior = float

maior = a
if (b > maior):
  maior = b

if (c > maior):
  maior = c

print("O maior dos três é :", maior)

# %%
print ("Idade de votar")

idade = int(input("Escreva sua idade:"))
resposta = input("Você tem titulo de eleitor?")

titulo = resposta.lower() == "sim"

if idade >=16 and titulo:
  print("Você pode votar")

else:
  print ("Você não pode votar")

# %%
print("Quem pode dirigir")
idade = int(input("Escreva sua idade:"))
resposta = input("Você tem carteira de motorista?")
carteira = resposta.lower() == "sim"

if idade >=18 and carteira:
  print("Você pode dirigir")

else:
  print("Você não pode dirigir")
# Out:
# Quem pode dirigir
# Escreva sua idade:18
# Você tem carteira de motorista?sim
# Você pode dirigir

# %%
print ("Desconto a vista 10%")
preco = float(input("Digite o preço do produto: "))

desconto = preco * 0.10
preco_final = preco - desconto

print("Desconto: R$", desconto)
print("Preço à vista: R$", preco_final)
# Out:
# Desconto a vista 10%
# Digite o preço do produto: 500
# Desconto: R$ 50.0
# Preço à vista: R$ 450.0

# %%
print ("CALCULADORA")
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

operacao = input("Digite a operação (+, -, *, /): ")

if operacao == "+":
    print("Resultado:", num1 + num2)

elif operacao == "-":
    print("Resultado:", num1 - num2)

elif operacao == "*":
    print("Resultado:", num1 * num2)

elif operacao == "/":
    print("Resultado:", num1 / num2)

else:
    print("Operação inválida")

# %%
print ("Entrada em evento: Maioridade e ingresso")
idade = int(input("Idade:"))
autorizacao = str (input("Possui o ingresso?")) .lower() == "sim"
if idade >=18 and autorizacao == True:
  print ("Você pode entrar no evento")

else:
  print("Você não pode entrar no evento")
# Out:
# Entrada em evento: Maioridade e ingresso
# Idade:18
# Possui o ingresso?não
# Você não pode entrar no evento

# %%
print ("Pratica esportiva de 12 a 17 anos com autorização dos pais")

idade = int(input("Idade:"))
autorizacao = str (input("Possui autorização para exercer ")) .lower() == "sim"
if idade >=12 and idade <=17 and autorizacao == True:
  print ("Você pode participar")

else:
 print("Você não pode participar")
# Out:
# Pratica esportiva de 12 a 17 anos com autorização dos pais
# Idade:17
# Possui autorização para exercer sim
# Você pode participar

# %%
print ("Pratica esportiva de 12 a 17 anos com autorização dos pais")

idade = int(input("Idade:"))
autorizacao = str (input("Possui autorização para exercer ")) .lower() == "sim"
if idade >=12 and idade <=17 and autorizacao == True:
  print ("Você pode participar")

else:
 print("Você não pode participar")
# Out:
# Pratica esportiva de 12 a 17 anos com autorização dos pais
# Idade:17
# Possui autorização para exercer sim
# Você pode participar

# %%
print ("Pratica esportiva de 12 a 17 anos com autorização dos pais")

idade = int(input("Idade:"))
autorizacao = str (input("Possui autorização para exercer ")) .lower() == "sim"
if idade >=12 and idade <=17 and autorizacao == True:
  print ("Você pode participar")

else:
 print("Você não pode participar")
# Out:
# Pratica esportiva de 12 a 17 anos com autorização dos pais
# Idade:17
# Possui autorização para exercer sim
# Você pode participar

# %%
print ("Classificação triangulo: isoceles,equilatero,escaleno ")
lado1 = float(input("Digite o primeiro lado: "))
lado2 = float(input("Digite o segundo lado: "))
lado3 = float(input("Digite o terceiro lado: "))

if lado1 == lado2 and lado2 == lado3:
    print("Triângulo equilátero")

elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
    print("Triângulo isósceles")

else:
    print("Triângulo escaleno")
# Out:
# Classificação triangulo: isoceles,equilatero,escaleno
# Digite o primeiro lado: 5
# Digite o segundo lado: 6
# Digite o terceiro lado: 7
# Triângulo escaleno

# %%
print("Chuva")
resposta = str (input("Está chovendo? sim/não:")) .lower() == "sim"
chovendo = resposta
if chovendo == True:
  chovendo == "sim"
  print("Leve um guarda chuva")

else:
  print("Saia tranquilo")
# Out:
# Chuva
# Está chovendo? sim/não:não
# Saia tranquilo

# %%
print ("Classificação faixa etaria")
idade = int(input("Digite sua idade: "))

if idade <= 12:
    print("Criança")

elif idade <= 17:
    print("Adolescente")

elif idade <= 59:
    print("Adulto")

else:
    print("Idoso")

# %%
print("FORMAS DE PAGAMENTO")
print("1 - Dinheiro")
print("2 - Pix")
print("3 - Cartão de crédito")
print("4 - Cartão de débito")

opcao = int(input("Escolha uma opção: "))

if opcao == 1:
    print("Pagamento em dinheiro")

elif opcao == 2:
    print("Pagamento via Pix")

elif opcao == 3:
    print("Pagamento no cartão de crédito")

elif opcao == 4:
    print("Pagamento no cartão de débito")

else:
    print("Opção inválida")

# %%
print ("desconto 10% 15% ou 30%")
preco = float(input("Digite o preço do produto: "))

print("1 - Desconto de 10%")
print("2 - Desconto de 15%")
print("3 - Desconto de 30%")

opcao = int(input("Escolha uma opção: "))

if opcao == 1:
    desconto = preco * 0.10

elif opcao == 2:
    desconto = preco * 0.15

elif opcao == 3:
    desconto = preco * 0.30

else:
    desconto = 0
    print("Opção inválida")

preco_final = preco - desconto

print("Valor do desconto: R$", desconto)
print("Preço final: R$", preco_final)
